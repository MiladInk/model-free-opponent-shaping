# %%
import json
import numpy as np
import matplotlib

# %%
with open('/Users/miladaghajohari/PycharmProjects/model-free-opponent-shaping/src/coin_game/mfos_coin_game_milad_7x7_1/out_1000.json') as f:
    data = json.load(f)
data[0].keys()
# Out:
# dict_keys(['episode', 'rew', 'opp_rew', 'p1_opp', 'p2_opp', 'p1_self', 'p2_self'])

# %%
p2_opp = np.array([i['p2_opp'] for i in data])
p1_opp = np.array([i['p1_opp'] for i in data])
p1_self = np.array([i['p1_self'] for i in data])
p2_self = np.array([i['p2_self'] for i in data])

# %%
import matplotlib.pyplot as plt
plt.plot(p2_self/(p2_opp+p2_self))

# %%
plt.plot([i['rew']/256 for i in data])

# %%
plt.plot([i['opp_rew']/256 for i in data])
